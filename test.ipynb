# %% [markdown]
# ### Imports

# %%
import logging
import datetime

from IPython.core.display import display, HTML

from scripts.main import *
from scripts.retrieve_data import *
from scripts.extract_data import *

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# set the width of the notebook
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ### Prepare for tests

# %%
create_logger()
config = load_config()
config['main']['start_date'] = '2019-09-05'
config['main']['end_date'] = '2019-09-05'

# %%
retrieve_and_save_single_day_data_from_PACS(config, datetime.datetime(2019, 9, 5))
# Out:
# 2019-11-29 12:19:20,699|retrieve_and_save_single_day_d: 92|WARNING| Processing 20190905: no save file found at "data\2019\2019-09\2019-09-05.pkl"
# 2019-11-29 12:19:20,701|find_studies_for_day          :168|INFO   | Processing 20190905: retrieving all studies from PACS
# 2019-11-29 12:19:21,225|find_series_for_studies       :221|WARNING| Finding all series for 37 studie(s)
# 2019-11-29 12:19:21,416|find_series_for_studies       :227|WARNING| Skipping study because there are no usable Series associated with it
# 2019-11-29 12:19:27,147|find_series_for_studies       :263|WARNING| Skipping study because it is not from CHUV (but from "CLINIQUE DE LA SOURCE")
# 2019-11-29 12:19:29,460|find_series_for_studies       :245|WARNING| Multiple institution names for study: "PET CT CHUV / Centre hospitalier universitaire vaudois"
# 2019-11-29 12:19:29,728|find_series_for_studies       :263|WARNING| Skipping study because it is not from CHUV (but from "HRC")
# 2019-11-29 12:19:31,383|find_series_for_study         :360|WARNING| Discarding 1 NM series because they have more than one instance
# 2019-11-29 12:19:31,390|find_series_for_studies       :245|WARNING| Multiple institution names for study: "Radiologie CHUV / MEDECINE NUCLEAIRE CHUV LAUSANNE"
# 2019-11-29 12:19:34,220|find_series_for_studies       :279|WARNING| Found 276 series in total for the 37 studies
# 2019-11-29 12:19:34,228|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 50 series, trial 0, batch 0 - 49
# 2019-11-29 12:19:34,252|fetch_info_for_series         :415|WARNING| Getting CT/PT data (78 queries)
# 2019-11-29 12:19:34,256|download_data_dcm4che         :727|INFO   | Getting data for 78 queries
# 2019-11-29 12:19:41,543|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:19:52,097|read_DICOM_files              :854|WARNING| Reading in 78 DICOM file(s)
# 2019-11-29 12:19:52,673|fetch_info_for_series         :427|WARNING| Getting NM data (10 queries)
# 2019-11-29 12:19:52,677|download_data_dcm4che         :727|INFO   | Getting data for 10 queries
# 2019-11-29 12:19:52,864|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:20:07,111|read_DICOM_files              :854|WARNING| Reading in 10 DICOM file(s)
# 2019-11-29 12:20:07,270|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 50 series, trial 0, batch 50 - 99
# 2019-11-29 12:20:07,279|fetch_info_for_series         :415|WARNING| Getting CT/PT data (77 queries)
# 2019-11-29 12:20:07,281|download_data_dcm4che         :727|INFO   | Getting data for 77 queries
# 2019-11-29 12:20:15,410|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:20:34,220|read_DICOM_files              :854|WARNING| Reading in 77 DICOM file(s)
# 2019-11-29 12:20:34,878|fetch_info_for_series         :427|WARNING| Getting NM data (9 queries)
# 2019-11-29 12:20:34,882|download_data_dcm4che         :727|INFO   | Getting data for 9 queries
# 2019-11-29 12:20:35,035|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:20:40,267|read_DICOM_files              :854|WARNING| Reading in 9 DICOM file(s)
# 2019-11-29 12:20:40,390|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 50 series, trial 0, batch 100 - 149
# 2019-11-29 12:20:40,402|fetch_info_for_series         :415|WARNING| Getting CT/PT data (92 queries)
# 2019-11-29 12:20:40,404|download_data_dcm4che         :727|INFO   | Getting data for 92 queries
# 2019-11-29 12:20:49,518|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:21:07,053|read_DICOM_files              :854|WARNING| Reading in 92 DICOM file(s)
# 2019-11-29 12:21:07,782|fetch_info_for_series         :427|WARNING| Getting NM data (3 queries)
# 2019-11-29 12:21:07,785|download_data_dcm4che         :727|INFO   | Getting data for 3 queries
# 2019-11-29 12:21:07,807|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:21:18,017|read_DICOM_files              :854|WARNING| Reading in 3 DICOM file(s)
# 2019-11-29 12:21:18,092|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 50 series, trial 0, batch 150 - 199
# 2019-11-29 12:21:18,101|fetch_info_for_series         :415|WARNING| Getting CT/PT data (76 queries)
# 2019-11-29 12:21:18,105|download_data_dcm4che         :727|INFO   | Getting data for 76 queries
# 2019-11-29 12:21:24,385|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:21:53,915|read_DICOM_files              :854|WARNING| Reading in 76 DICOM file(s)
# 2019-11-29 12:21:54,531|fetch_info_for_series         :427|WARNING| Getting NM data (11 queries)
# 2019-11-29 12:21:54,535|download_data_dcm4che         :727|INFO   | Getting data for 11 queries
# 2019-11-29 12:21:54,761|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:22:09,052|read_DICOM_files              :854|WARNING| Reading in 12 DICOM file(s)
# 2019-11-29 12:22:09,213|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 50 series, trial 0, batch 200 - 249
# 2019-11-29 12:22:09,224|fetch_info_for_series         :415|WARNING| Getting CT/PT data (78 queries)
# 2019-11-29 12:22:09,228|download_data_dcm4che         :727|INFO   | Getting data for 78 queries
# 2019-11-29 12:22:16,486|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:22:26,909|read_DICOM_files              :854|WARNING| Reading in 78 DICOM file(s)
# 2019-11-29 12:22:27,496|fetch_info_for_series         :427|WARNING| Getting NM data (9 queries)
# 2019-11-29 12:22:27,500|download_data_dcm4che         :727|INFO   | Getting data for 9 queries
# 2019-11-29 12:22:27,601|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:22:33,838|read_DICOM_files              :854|WARNING| Reading in 9 DICOM file(s)
# 2019-11-29 12:22:33,966|retrieve_and_save_single_day_d:124|INFO   | Fetching info for 26 series, trial 0, batch 250 - 275
# 2019-11-29 12:22:33,973|fetch_info_for_series         :415|WARNING| Getting CT/PT data (34 queries)
# 2019-11-29 12:22:33,976|download_data_dcm4che         :727|INFO   | Getting data for 34 queries
# 2019-11-29 12:22:35,417|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:22:44,792|read_DICOM_files              :854|WARNING| Reading in 34 DICOM file(s)
# 2019-11-29 12:22:45,045|fetch_info_for_series         :427|WARNING| Getting NM data (8 queries)
# 2019-11-29 12:22:45,048|download_data_dcm4che         :727|INFO   | Getting data for 8 queries
# 2019-11-29 12:22:45,111|download_data_dcm4che         :781|INFO   | Waiting for responses
# 2019-11-29 12:22:50,360|read_DICOM_files              :854|WARNING| Reading in 8 DICOM file(s)
# 2019-11-29 12:22:50,474|retrieve_and_save_single_day_d:144|WARNING| Found 0 failed series and 275 successful series
# 2019-11-29 12:22:50,482|retrieve_and_save_single_day_d:149|INFO   | Saving 275 series

# %%
df = extract_transform_and_save_data_from_files(config)
#display(df)
with pd.option_context("display.max_rows", 1000): display(df)
# Out:
# 2019-11-29 12:25:01,182|extract_transform_and_save_dat: 18|INFO   | Extracting data from files
#     End Time                          Institution Name                Machine  \
# 0     080845  Centre hospitalier universitaire vaudois             Biograph64
# 1     080922  Centre hospitalier universitaire vaudois             Biograph64
# 2     081355  Centre hospitalier universitaire vaudois  Biograph64_Vision 600
#
# 273   165537                           Radiologie CHUV                Encore2
# 274   165537                           Radiologie CHUV                Encore2
#
#     Modality Number of Series Related Instances Patient ID  \
# 0         CT                                  1     773919
# 1         CT                                132     773919
# 2         PT                               1056     773919
# 3         PT                               1056     773919
# 4         PT                               1056     773919
# 5         PT                                132     773919
# 6         PT                                132     773919
# 7         PT                               2772     773919
# 8         PT                               1056     773919
# 9         PT                               1056     773919
# 10        PT                               1056     773919
# 11        PT                                132     773919
# 12        PT                                132     773919
# 13        PT                               2772     773919
# 14        NM                                  1     978677
# 15        NM                                  1     978677
# 16        NM                                  1     978677
# 17        NM                                  1    2289414
# 18        NM                                  1    2289414
# 19        NM                                  1    2289414
# 20        NM                                  1    2289414
# 21        NM                                  1    2289414
# 22        PT                                201    2289414
# 23        PT                                201    2289414
# 24        CT                                  2    2289414
# 25        CT                                196    2289414
# 26        CT                                559    2289414
# 27        CT                                559    2289414
# 28        NM                                  1    2289414
# 29        NM                                  1    2289414
# 30        CT                                  1     814598
# 31        CT                                132     814598
# 32        PT                               1056     814598
# 33        PT                               1056     814598
# 34        PT                               1056     814598
# 35        PT                                132     814598
# 36        PT                                132     814598
# 37        PT                               2772     814598
# 38        PT                               1056     814598
# 39        PT                               1056     814598
# 40        PT                               1056     814598
# 41        PT                                132     814598
# 42        PT                                132     814598
# 43        PT                               2772     814598
# 44        CT                                  2    2578213
# 45        CT                               1092    2578213
# 46        CT                                324    2578213
# 47        CT                                335    2578213
# 48        PT                                335    2578213
# 49        PT                                335    2578213
# 50        PT                                335    2578213
# 51        CT                                  1     239213
# 52        CT                                787     239213
# 53        PT                                787     239213
# 54        PT                                787     239213
# 55        PT                                787     239213
# 56        CT                                787     239213
# 57        CT                               1836     239213
# 58        CT                                562     239213
# 59        NM                                  1     978677
# 60        NM                                  1     978677
# 61        CT                                  2     978677
# 62        CT                                229     978677
# 63        CT                                  2      82444
# 64        CT                                327      82444
# 65        CT                                413      82444
# 66        CT                                825      82444
# 67        PT                                623      82444
# 68        PT                                623      82444
# 69        PT                                623      82444
# 70        CT                                  1    2968590
# 71        CT                                759    2968590
# 72        PT                                759    2968590
# 73        PT                                759    2968590
# 74        PT                                759    2968590
# 75        CT                                759    2968590
# 76        CT                               1770    2968590
# 77        CT                                590    2968590
# 78        CT                                  1    3158201
# 79        CT                                 51    3158201
# 80        NM                                  1    3158201
# 81        NM                                  1    3158201
# 82        NM                                  1    3158201
# 83        NM                                  1    3158201
# 84        NM                                  1    3158201
# 85        CT                                  2    1036413
# 86        CT                                299    1036413
# 87        CT                                301    1036413
# 88        CT                                975    1036413
# 89        PT                                299    1036413
# 90        PT                                299    1036413
# 91        PT                                299    1036413
# 92        NM                                  1     444856
# 93        NM                                  1     444856
# 94        CT                                  2     444856
# 95        CT                                173     444856
# 96        CT                                344     444856
# 97        CT                                344     444856
# 98        CT                                  1    3201711
# 99        CT                                  1    3201711
# 100       CT                               1396    3201711
# 101       PT                               1396    3201711
# 102       PT                               1396    3201711
# 103       PT                               1396    3201711
# 104       CT                               1396    3201711
# 105       CT                               3256    3201711
# 106       CT                                557    3201711
# 107       CT                                  2    2487850
# 108       CT                                291    2487850
# 109       CT                                413    2487850
# 110       CT                                825    2487850
# 111       PT                                623    2487850
# 112       PT                                623    2487850
# 113       PT                                623    2487850
# 114       NM                                  1     810705
# 115       CT                                  1     457891
# 116       CT                                564     457891
# 117       PT                                564     457891
# 118       PT                                564     457891
# 119       PT                                564     457891
# 120       CT                                806     457891
# 121       CT                               1880     457891
# 122       CT                                680     457891
# 123       CT                                  2    3118607
# 124       CT                                299    3118607
# 125       CT                                346    3118607
# 126       CT                                975    3118607
# 127       PT                                299    3118607
# 128       PT                                299    3118607
# 129       PT                                299    3118607
# 130       CT                                  1     456810
# 131       CT                                912     456810
# 132       PT                                912     456810
# 133       PT                                912     456810
# 134       PT                                912     456810
# 135       CT                                912     456810
# 136       CT                               2126     456810
# 137       CT                                440     456810
# 138       CT                                  2    3003478
# 139       CT                               1092    3003478
# 140       CT                                327    3003478
# 141       CT                                335    3003478
# 142       PT                                335    3003478
# 143       PT                                335    3003478
# 144       PT                                335    3003478
# 145       NM                                  1     810705
# 146       NM                                  1     810705
# 147       CT                                  2     810705
# 148       CT                                160     810705
# 149       CT                                286     810705
# 150       CT                                286     810705
# 151       CT                                  1     467662
# 152       CT                                749     467662
# 153       PT                                749     467662
# 154       PT                                749     467662
# 155       PT                                749     467662
# 156       CT                                749     467662
# 157       CT                               1748     467662
# 158       CT                                621     467662
# 159       CT                                  2    2794636
# 160       CT                                 47    2794636
# 161       PT                                376    2794636
# 162       PT                                 47    2794636
# 163       PT                                 47    2794636
# 164       CT                                  1    2794636
# 165       CT                               1303    2794636
# 166       PT                               1302    2794636
# 167       PT                               1302    2794636
# 168       PT                               1302    2794636
# 169       CT                               1303    2794636
# 170       CT                               3039    2794636
# 171       CT                                531    2794636
# 172       NM                                  1    2972412
# 173       NM                                  1    2972412
# 174       NM                                  1    2972412
# 175       NM                                  1    2972412
# 176       CT                                  2    2972412
# 177       CT                                118    2972412
# 178       NM                                  1     650122
# 179       NM                                  2     650122
# 180       PT                                 97     650122
# 181       PT                                 98     650122
# 182       CT                                  2     650122
# 183       CT                                126     650122
# 184       CT                                 95     650122
# 185       NM                                  1     650122
# 186       NM                                  1     650122
# 187       NM                                  1     650122
# 188       NM                                  1     650122
# 189       CT                                  2    3065862
# 190       CT                                299    3065862
# 191       CT                                310    3065862
# 192       CT                                975    3065862
# 193       PT                                299    3065862
# 194       PT                                299    3065862
# 195       PT                                299    3065862
# 196       CT                                  2     883254
# 197       CT                                335     883254
# 198       CT                                361     883254
# 199       CT                                392     883254
# 200       PT                                335     883254
# 201       PT                                335     883254
# 202       PT                                335     883254
# 203       CT                                  1    3283684
# 204       CT                                815    3283684
# 205       PT                                815    3283684
# 206       PT                                815    3283684
# 207       PT                                815    3283684
# 208       PT                                815    3283684
# 209       CT                                815    3283684
# 210       CT                                601    3283684
# 211       CT                                  1    2562062
# 212       CT                                923    2562062
# 213       PT                                923    2562062
# 214       PT                                923    2562062
# 215       PT                                923    2562062
# 216       CT                                923    2562062
# 217       CT                               2154    2562062
# 218       CT                                541    2562062
# 219       CT                                  2    3120532
# 220       CT                                299    3120532
# 221       CT                                356    3120532
# 222       CT                                975    3120532
# 223       PT                                299    3120532
# 224       PT                                299    3120532
# 225       PT                                299    3120532
# 226       NM                                  1     602693
# 227       NM                                  1     602693
# 228       NM                                  1     602693
# 229       NM                                  1     602693
# 230       CT                                  2     602693
# 231       CT                                144     602693
# 232       CT                                268     602693
# 233       CT                                268     602693
# 234       CT                                  1    3158201
# 235       CT                                 51    3158201
# 236       NM                                  1    3158201
# 237       NM                                  1    3158201
# 238       NM                                  1    3158201
# 239       NM                                  1    3158201
# 240       NM                                  1    3158201
# 241       CT                                  1     514618
# 242       CT                                768     514618
# 243       PT                                768     514618
# 244       PT                                768     514618
# 245       PT                                768     514618
# 246       CT                                768     514618
# 247       CT                               1791     514618
# 248       CT                                458     514618
# 249       CT                                751     514618
# 250       CT                                  1     410160
# 251       CT                                  1     410160
# 252       CT                                876     410160
# 253       PT                                876     410160
# 254       PT                                876     410160
# 255       PT                                876     410160
# 256       CT                                876     410160
# 257       CT                               2044     410160
# 258       CT                                517     410160
# 259       NM                                  1    3282403
# 260       NM                                  1    3282403
# 261       NM                                  1    3282403
# 262       CT                                  2    3282403
# 263       CT                                 56    3282403
# 264       CT                                275    3282403
# 265       CT                                275    3282403
# 266       NM                                  1    3282403
# 267       NM                                  1    3282403
# 268       NM                                  1    3282403
# 269       CT                                  2    3282403
# 270       CT                                 55    3282403
# 271       CT                                272    3282403
# 272       CT                                272    3282403
# 273       NM                                  1    3282403
# 274       NM                                  1    3282403
#
#                               Protocol Name Series Date  \
# 0                          2_Pet_Rb82_Coeur    20190905
# 1                          2_Pet_Rb82_Coeur    20190905
# 2                                       NaN    20190905
# 3                                       NaN    20190905
# 4                                       NaN    20190905
# 5                                       NaN    20190905
# 6                                       NaN    20190905
# 7                                       NaN    20190905
# 8                                       NaN    20190905
# 9                                       NaN    20190905
# 10                                      NaN    20190905
# 11                                      NaN    20190905
# 12                                      NaN    20190905
# 13                                      NaN    20190905
# 14                             PTHY PINHOLE    20190905
# 15                             PTHY PINHOLE    20190905
# 16                             PTHY PINHOLE    20190905
# 17                        13306.0.96426045@    20190905
# 18                        13306.0.96426045@    20190905
# 19                        13306.0.96426045@    20190905
# 20                        13306.0.96426045@    20190905
# 21                        13306.0.96426045@    20190905
# 22                        13306.0.96426045@    20190905
# 23                        13306.0.96426045@    20190905
# 24                  SPECT_GENOUX_QuantxBone    20190905
# 25                  SPECT_GENOUX_QuantxBone    20190905
# 26                  SPECT_GENOUX_QuantxBone    20190905
# 27                  SPECT_GENOUX_QuantxBone    20190905
# 28                        13306.0.96426045@    20190905
# 29                        13306.0.96426045@    20190905
# 30                         2_Pet_Rb82_Coeur    20190905
# 31                         2_Pet_Rb82_Coeur    20190905
# 32                                      NaN    20190905
# 33                                      NaN    20190905
# 34                                      NaN    20190905
# 35                                      NaN    20190905
# 36                                      NaN    20190905
# 37                                      NaN    20190905
# 38                                      NaN    20190905
# 39                                      NaN    20190905
# 40                                      NaN    20190905
# 41                                      NaN    20190905
# 42                                      NaN    20190905
# 43                                      NaN    20190905
# 44             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 45             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 46             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 47             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 48             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 49             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 50             1.4 PET-CT TRONC HAUT 1MIN30    20190905
# 51                     1_Pet_FDG_Tronc_Flow    20190905
# 52                     1_Pet_FDG_Tronc_Flow    20190905
# 53                                      NaN    20190905
# 54                                      NaN    20190905
# 55                                      NaN    20190905
# 56                     1_Pet_FDG_Tronc_Flow    20190905
# 57                     1_Pet_FDG_Tronc_Flow    20190905
# 58                     1_Pet_FDG_Tronc_Flow    20190905
# 59           User&PARATHYROIDE&PARATHYROIDE    20190905
# 60           User&PARATHYROIDE&PARATHYROIDE    20190905
# 61   1.1 NUC Tete et Cou  Extra Low Dose MN    20190905
# 62   1.1 NUC Tete et Cou  Extra Low Dose MN    20190905
# 63              1.9 PT-CT Corps Entier HAUT    20190905
# 64              1.9 PT-CT Corps Entier HAUT    20190905
# 65              1.9 PT-CT Corps Entier HAUT    20190905
# 66              1.9 PT-CT Corps Entier HAUT    20190905
# 67              1.9 PT-CT Corps Entier HAUT    20190905
# 68              1.9 PT-CT Corps Entier HAUT    20190905
# 69              1.9 PT-CT Corps Entier HAUT    20190905
# 70                     1_Pet_FDG_Tronc_Flow    20190905
# 71                     1_Pet_FDG_Tronc_Flow    20190905
# 72                                      NaN    20190905
# 73                                      NaN    20190905
# 74                                      NaN    20190905
# 75                     1_Pet_FDG_Tronc_Flow    20190905
# 76                     1_Pet_FDG_Tronc_Flow    20190905
# 77                     1_Pet_FDG_Tronc_Flow    20190905
# 78                               SPECT_REST    20190905
# 79                               SPECT_REST    20190905
# 80                        13306.0.96426067@    20190905
# 81                        13306.0.96426067@    20190905
# 82                        13306.0.96426067@    20190905
# 83                        13306.0.96426067@    20190905
# 84                        13306.0.96426067@    20190905
# 85                    1.2 PET-CT TRONC HAUT    20190905
# 86                    1.2 PET-CT TRONC HAUT    20190905
# 87                    1.2 PET-CT TRONC HAUT    20190905
# 88                    1.2 PET-CT TRONC HAUT    20190905
# 89                    1.2 PET-CT TRONC HAUT    20190905
# 90                    1.2 PET-CT TRONC HAUT    20190905
# 91                    1.2 PET-CT TRONC HAUT    20190905
# 92            User&POUMONS&PERFUSION pre-op    20190905
# 93            User&POUMONS&PERFUSION pre-op    20190905
# 94        5.10 NUC Thorax Extra Low Dose MN    20190905
# 95        5.10 NUC Thorax Extra Low Dose MN    20190905
# 96        5.10 NUC Thorax Extra Low Dose MN    20190905
# 97        5.10 NUC Thorax Extra Low Dose MN    20190905
# 98               1_Pet_FDG_CorpsEntier_Flow    20190905
# 99               1_Pet_FDG_CorpsEntier_Flow    20190905
# 100              1_Pet_FDG_CorpsEntier_Flow    20190905
# 101                                     NaN    20190905
# 102                                     NaN    20190905
# 103                                     NaN    20190905
# 104              1_Pet_FDG_CorpsEntier_Flow    20190905
# 105              1_Pet_FDG_CorpsEntier_Flow    20190905
# 106              1_Pet_FDG_CorpsEntier_Flow    20190905
# 107     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 108     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 109     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 110     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 111     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 112     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 113     1.11 PT-CT Corps Entier HAUT 1MIN30    20190905
# 114             User&POUMONS&VENTILATION TC    20190905
# 115              3_Pet_Ga68_PSMA_Tronc_Flow    20190905
# 116              3_Pet_Ga68_PSMA_Tronc_Flow    20190905
# 117                                     NaN    20190905
# 118                                     NaN    20190905
# 119                                     NaN    20190905
# 120              3_Pet_Ga68_PSMA_Tronc_Flow    20190905
# 121              3_Pet_Ga68_PSMA_Tronc_Flow    20190905
# 122              3_Pet_Ga68_PSMA_Tronc_Flow    20190905
# 123             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 124             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 125             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 126             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 127             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 128             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 129             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 130                    1_Pet_FDG_Tronc_Flow    20190905
# 131                    1_Pet_FDG_Tronc_Flow    20190905
# 132                                     NaN    20190905
# 133                                     NaN    20190905
# 134                                     NaN    20190905
# 135                    1_Pet_FDG_Tronc_Flow    20190905
# 136                    1_Pet_FDG_Tronc_Flow    20190905
# 137                    1_Pet_FDG_Tronc_Flow    20190905
# 138             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 139             1.5 PET-CT TRONC BAS 1MIN30    20190905
# 140             1.5 PET-CT TRONC BAS 1MIN30    20190905
# ...
# 271                                   GGL SEINS BILAT
# 272                                   GGL SEINS BILAT
# 273                                   GGL SEINS BILAT
# 274                                   GGL SEINS BILAT
#
#                                     Study Instance UID
# 0    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 1    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 2    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 3    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 4    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 5    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 6    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 7    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 8    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 9    1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 10   1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 11   1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 12   1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 13   1.2.826.0.1.3680043.2.146.2.20.773919.19002057...
# 14   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 15   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 16   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 17   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 18   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 19   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 20   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 21   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 22   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 23   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 24   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 25   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 26   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 27   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 28   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 29   1.2.826.0.1.3680043.2.146.2.20.2289414.1900209...
# 30   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 31   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 32   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 33   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 34   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 35   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 36   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 37   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 38   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 39   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 40   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 41   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 42   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 43   1.2.826.0.1.3680043.2.146.2.20.814598.19002057...
# 44   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 45   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 46   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 47   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 48   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 49   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 50   1.2.826.0.1.3680043.2.146.2.20.2578213.1900153...
# 51   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 52   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 53   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 54   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 55   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 56   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 57   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 58   1.2.826.0.1.3680043.2.146.2.20.239213.19002012...
# 59   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 60   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 61   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 62   1.2.826.0.1.3680043.2.146.2.20.978677.19001942...
# 63   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 64   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 65   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 66   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 67   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 68   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 69   1.2.826.0.1.3680043.2.146.2.20.82444.1900144093.0
# 70   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 71   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 72   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 73   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 74   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 75   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 76   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 77   1.2.826.0.1.3680043.2.146.2.20.2968590.1900203...
# 78   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 79   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 80   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 81   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 82   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 83   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 84   1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 85   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 86   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 87   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 88   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 89   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 90   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 91   1.2.826.0.1.3680043.2.146.2.20.1036413.1900182...
# 92   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 93   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 94   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 95   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 96   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 97   1.2.826.0.1.3680043.2.146.2.20.444856.19001883...
# 98   1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 99   1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 100  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 101  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 102  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 103  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 104  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 105  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 106  1.2.826.0.1.3680043.2.146.2.20.3201711.1900156...
# 107  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 108  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 109  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 110  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 111  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 112  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 113  1.2.826.0.1.3680043.2.146.2.20.2487850.1900204...
# 114  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 115  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 116  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 117  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 118  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 119  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 120  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 121  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 122  1.2.826.0.1.3680043.2.146.2.20.457891.19002087...
# 123  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 124  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 125  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 126  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 127  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 128  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 129  1.2.826.0.1.3680043.2.146.2.20.3118607.1900208...
# 130  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 131  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 132  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 133  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 134  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 135  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 136  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 137  1.2.826.0.1.3680043.2.146.2.20.456810.19002095...
# 138  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 139  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 140  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 141  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 142  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 143  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 144  1.2.826.0.1.3680043.2.146.2.20.3003478.1900209...
# 145  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 146  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 147  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 148  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 149  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 150  1.2.826.0.1.3680043.2.146.2.20.810705.19002082...
# 151  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 152  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 153  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 154  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 155  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 156  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 157  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 158  1.3.12.2.1107.5.1.4.10001.30000019090507052118...
# 159  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 160  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 161  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 162  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 163  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 164  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 165  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 166  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 167  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 168  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 169  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 170  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 171  1.2.826.0.1.3680043.2.146.2.20.2794636.1900208...
# 172  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 173  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 174  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 175  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 176  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 177  1.2.826.0.1.3680043.2.146.2.20.2972412.1900200...
# 178  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 179  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 180  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 181  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 182  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 183  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 184  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 185  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 186  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 187  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 188  1.2.826.0.1.3680043.2.146.2.20.650122.19001990...
# 189  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 190  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 191  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 192  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 193  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 194  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 195  1.2.826.0.1.3680043.2.146.2.20.3065862.1900209...
# 196  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 197  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 198  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 199  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 200  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 201  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 202  1.2.826.0.1.3680043.2.146.2.20.883254.19002084...
# 203  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 204  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 205  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 206  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 207  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 208  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 209  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 210  1.2.826.0.1.3680043.2.146.2.20.3283684.1900210...
# 211  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 212  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 213  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 214  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 215  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 216  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 217  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 218  1.2.826.0.1.3680043.2.146.2.20.2562062.1900208...
# 219  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 220  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 221  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 222  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 223  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 224  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 225  1.2.826.0.1.3680043.2.146.2.20.3120532.1900209...
# 226  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 227  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 228  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 229  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 230  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 231  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 232  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 233  1.2.826.0.1.3680043.2.146.2.20.602693.19002056...
# 234  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 235  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 236  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 237  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 238  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 239  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 240  1.2.826.0.1.3680043.2.146.2.20.3158201.1900204...
# 241  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 242  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 243  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 244  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 245  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 246  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 247  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 248  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 249  1.2.826.0.1.3680043.2.146.2.20.514618.19002100...
# 250  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 251  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 252  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 253  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 254  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 255  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 256  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 257  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 258  1.2.826.0.1.3680043.2.146.2.20.410160.19002102...
# 259  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 260  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 261  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 262  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 263  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 264  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 265  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 266  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 267  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 268  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 269  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 270  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 271  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 272  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 273  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...
# 274  1.2.826.0.1.3680043.2.146.2.20.3282403.1900205...

# %%
df_failed_with_info = fetch_info_for_series(config, df_failed)

# %%
df2 = pd.concat([df, df_failed_with_info], sort=True)
df2.drop_duplicates('Series Instance UID')

# %%
df_rescued_series = df_failed_with_info.copy()
df_failed_series = df_rescued_series[
            (df_rescued_series['Start Time'].isnull())
            | (df_rescued_series['End Time'].isnull())
            | (df_rescued_series['Machine'] == '')
            | (df_rescued_series['Institution Name'] == '')]
# exclude series where some information could still not be gathered (e.g. no end time or no machine)
df_rescued_series = df_rescued_series.loc[~df_rescued_series.index.isin(df_failed_series.index), :]
df2 = pd.concat([df, df_rescued_series], sort=True)
df_failed_series
df2

# %% [markdown]
# ### Find all studies and series

# %%
df_studies = find_studies_for_day(config, '20191028', ['PT', 'NM'])
df_all_series = find_series_for_studies(config, df_studies)

# %%
set(df_all_series[df_all_series['Number of Series Related Instances'].astype(int) > 1].Modality)

# %%
df_series = df_all_series.copy()

# %% [markdown]
# df_series_subset = pd.concat([df_all_series[df_all_series.Modality == modality].head(n = 10) for modality in set(df_all_series.Modality)]).sort_values('Series Time').reset_index(drop=True)
# df_series_subset
# df_series = df_series_subset.copy()
# df_series

# %%
df_series = fetch_info_for_series(config, df_series)

# %%
df_series

# %% [markdown]
# ### Step by step before turing it to an API

# %%
# list of field names to extract for each modality
to_fetch_fields_ctpt = ['SeriesInstanceUID', 'PatientID', 'InstanceNumber', 'ManufacturerModelName',
    'AcquisitionTime', 'Modality']
to_fetch_fields_nm = ['SeriesInstanceUID', 'PatientID', 'InstanceNumber', 'ManufacturerModelName',
    'AcquisitionTime', 'Modality', 'ActualFrameDuration', 'NumberOfFrames', '0x00540032', '0x00540052']

# create modality specific masks of the DataFrame
df_series_ctpt = df_series[df_series['Modality'].isin(['PT', 'CT'])]
df_series_nm = df_series[df_series['Modality'] == 'NM']
display(df_series_ctpt)
display(df_series_nm)

# %%
# prepare the CT/PT queries for the first instance (first image)
query_dicts_ctpt = list(df_series_ctpt.apply(lambda row: {
    'SeriesDate': row['Series Date'],
    'PatientID': row['Patient ID'],
    'SeriesInstanceUID': row['Series Instance UID'],
    'InstanceNumber': '1'
}, axis=1))
# prepare the CT/PT queries for the last instance (last image)
df_last_frames = df_series_ctpt[df_series_ctpt['Number of Series Related Instances'] != '1']
if len(df_last_frames) > 0:
    query_dicts_ctpt.extend(
        df_last_frames.apply(lambda row: {
            'SeriesDate': row['Series Date'],
            'PatientID': row['Patient ID'],
            'SeriesInstanceUID': row['Series Instance UID'],
            'InstanceNumber': row['Number of Series Related Instances']
        }, axis=1))
# fetch the CT/PT data
logging.info('Getting CT/PT data ({} queries)'.format(len(query_dicts_ctpt)))
df_info_ctpt = get_data(config, query_dicts_ctpt, to_fetch_fields_ctpt)

# prepare the NM queries for the first instance (first image)
query_dicts_nm = list(df_series_nm.apply(lambda row: {
    'SeriesDate': row['Series Date'],
    'PatientID': row['Patient ID'],
    'SeriesInstanceUID': row['Series Instance UID']
}, axis=1))
# fetch the NM data
logging.info('Getting NM data ({} queries)'.format(len(query_dicts_nm)))
df_info_nm = get_data(config, query_dicts_nm, to_fetch_fields_nm)

# %%
df_series_save = df_series.copy()
df_info_ctpt_save = df_info_ctpt.copy()

# %%
df_series = df_series_save.copy()
df_info_ctpt_save = df_info_ctpt_save.copy()

# get the images with a single instance
single_instances_UIDs = df_series.loc[
    (df_series['Series Instance UID'].isin(df_info_ctpt['SeriesInstanceUID']))\
    & (df_series['Number of Series Related Instances'] == '1'), 'Series Instance UID']
# duplicated them into the info DataFrame, so that they can also be merged together, as if there was two frames
df_info_ctpt_single_inst_copies = df_info_ctpt[df_info_ctpt['SeriesInstanceUID'].isin(single_instances_UIDs)].copy()
df_info_ctpt_single_inst_copies['InstanceNumber'] = 999999
df_info_ctpt_extended = pd.concat([df_info_ctpt, df_info_ctpt_single_inst_copies], sort=True)

# clean up the start times
df_info_ctpt_extended.loc[:, 'AcquisitionTime'] = df_info_ctpt_extended.loc[:, 'AcquisitionTime']\
    .apply(lambda t: str(t).split('.')[0])
# regroup the first and last instance rows on a single row
df_info_ctpt_merged = df_info_ctpt_extended[df_info_ctpt_extended['InstanceNumber'] == 1]\
    .merge(df_info_ctpt_extended[df_info_ctpt_extended['InstanceNumber'] > 1],
           on=['SeriesInstanceUID', 'PatientID', 'ManufacturerModelName', 'Modality'],
           suffixes=['_start', '_end'])
# rename the columns and keep the appropriate ones
df_info_ctpt_clean = df_info_ctpt_merged.rename(columns={
        'SeriesInstanceUID': 'Series Instance UID',
        'PatientID': 'Patient ID',
        'ManufacturerModelName': 'Machine',
        'AcquisitionTime_start': 'Start Time',
        'AcquisitionTime_end': 'End Time'})\
    .drop(columns=['InstanceNumber_start', 'InstanceNumber_end'])
# merge the info into the series DataFrame
df_series = df_series.merge(df_info_ctpt_clean, on=['Patient ID', 'Series Instance UID', 'Modality'],
    how='outer')
# keep only the relevant columns
for f in ['Start Time', 'End Time', 'Machine']:
    df_series[f] = df_series[f + '_y'].where(df_series[f + '_y'].notnull(), df_series[f + '_x'])
    df_series.drop(columns=[f + '_y', f + '_x'], inplace=True)

# %%
# clean up the start times
df_info_nm.loc[:, 'AcquisitionTime'] = df_info_nm.loc[:, 'AcquisitionTime']\
    .apply(lambda t: str(t).split('.')[0])
# use the AcquisitionTime as Start Time
df_info_nm['Start Time'] = df_info_nm['AcquisitionTime']
# call a function to calculate the End Times
df_info_nm['End Time'] = df_info_nm.apply(get_NM_series_end_time, axis=1)
# rename the columns and select the appropriate ones
df_info_nm_clean = df_info_nm.rename(columns={
        'SeriesInstanceUID': 'Series Instance UID',
        'PatientID': 'Patient ID',
        'ManufacturerModelName': 'Machine'})\
    [['Series Instance UID', 'Patient ID', 'Modality', 'Start Time', 'End Time', 'Machine']]
# merge the info into the series DataFrame
df_series = df_series.merge(df_info_nm_clean, on=['Patient ID', 'Series Instance UID', 'Modality'],
    how='outer')
# keep only the relevant columns
for f in ['Start Time', 'End Time', 'Machine']:
    df_series[f] = df_series[f + '_y'].where(df_series[f + '_y'].notnull(), df_series[f + '_x'])
    df_series.drop(columns=[f + '_y', f + '_x'], inplace=True)

# %%
dfmf = df_series[
    (df_series['Start Time'].isnull())
    | (df_series['End Time'].isnull())
    | (df_series['Machine'] == '')
    | (df_series['Institution Name'] == '')]
dfmf

# %%
dfmf2 = fetch_info_for_series(config, dfmf)
dfmf2

# %% [markdown]
# # Test to query all images in one query data set

# %% [markdown]
# ### Fetch info for all "first" CT/PT images

# %%
df_ctpt

# %%
df_info_ctpt_first = []
while len(df_info_ctpt_first) == 0:
    ds = Dataset()
    ds.QueryRetrieveLevel = 'IMAGE'
    ds.SeriesDate = '20191021'
    ds.SeriesInstanceUID = list(set(df_ctpt['Series Instance UID']))
    ds.PatientID =  list(set(df_ctpt['Patient ID']))
    ds.InstanceNumber = '1'
    ds.Modality = ['CT','PT']

    # fields to fetch from the DICOM header
    to_fetch_fields = ['SeriesInstanceUID', 'PatientID', 'InstanceNumber', 'ManufacturerModelName', 'AcquisitionTime',
        'Modality', 'ImageType', 'ActualFrameDuration', 'NumberOfFrames', '0x00540032', '0x00540052']

    # find information about this series by fetching some images
    df_info_ctpt_first = get_data(config, [ds], to_fetch_fields)

# %%
df_info_ctpt_first

# %% [markdown]
# ### Fetch info for all "last" CT/PT images

# %%
df_info_last = []
while len(df_info_last) == 0:
    ds = Dataset()
    ds.QueryRetrieveLevel = 'IMAGE'
    ds.SeriesDate = '20191021'
    ds.SeriesInstanceUID = list(set(df_ctpt['Series Instance UID']))
    ds.PatientID =  list(set(df_ctpt['Patient ID']))
    ds.InstanceNumber = list(set(df_ctpt['Number of Series Related Instances']))
    ds.Modality = ['CT','PT']

    # fields to fetch from the DICOM header
    to_fetch_fields = ['SeriesInstanceUID', 'PatientID', 'InstanceNumber', 'ManufacturerModelName', 'AcquisitionTime',
        'Modality', 'ImageType', 'ActualFrameDuration', 'NumberOfFrames', '0x00540032', '0x00540052']

    # find information about this series by fetching some images
    df_info_last = get_data(config, [ds], to_fetch_fields)

# %%
df_info_last.sort_values(by="InstanceNumber").drop_duplicates(subset=["SeriesInstanceUID"], keep="last").reset_index()
df_grouped.index += 1
df_grouped

# %% [markdown]
# ### Fetch info for all NM images

# %%
df_info_nm = []
while len(df_info_nm) == 0:
    ds = Dataset()
    ds.QueryRetrieveLevel = 'IMAGE'
    ds.SeriesDate = '20191021'
    ds.SeriesInstanceUID = list(set(df_nm['Series Instance UID'][0:5]))
    ds.PatientID =  list(set(df_nm['Patient ID'][0:5]))
    ds.Modality = 'NM'

    # fields to fetch from the DICOM header
    to_fetch_fields = ['SeriesInstanceUID', 'PatientID', 'ManufacturerModelName', 'AcquisitionTime',
        'Modality', 'ImageType', 'ActualFrameDuration', 'NumberOfFrames', '0x00540032', '0x00540052']

    # find information about this series by fetching some images
    df_info_nm = get_data(config, [ds], to_fetch_fields)

# %%
df_info_nm

# %% [markdown]
# ###  Merge the results

# %%
df_merged = df_series.merge(df_info.drop(columns='Modality').rename(columns={'SeriesInstanceUID': 'Series Instance UID'}), on='Series Instance UID', how='outer')
#df_merged[['Series Date', 'Series Time', 'AcquisitionTime']]
df_merged

# %%
df_info = []
while len(df_info) == 0:
    ds = Dataset()
    ds.QueryRetrieveLevel = 'IMAGE'
    ds.SeriesInstanceUID = df_series['Series Instance UID']
    ds.PatientID =  df_series['Patient ID']
    ds.Modality = 'NM'

    # fields to fetch from the DICOM header
    to_fetch_fields = ['SeriesInstanceUID', 'PatientID', 'InstanceNumber', 'ManufacturerModelName', 'AcquisitionTime',
        'Modality', 'ImageType', 'ActualFrameDuration', 'NumberOfFrames', '0x00540032', '0x00540052']

    # find information about this series by fetching some images
    df_info = get_data(config, [ds], to_fetch_fields)
